# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from datapipeline.utils.spark_session import get_spark_session

spark = get_spark_session("ML_Clustering")

# %%
ml_cluster_path = os.path.join(project_root, "sanewsstorage/ml/clusters")
articles_path   = os.path.join(project_root, "sanewsstorage/gold/articles_final")

cluster_df  = spark.read.format("delta").load(ml_cluster_path)
articles_df = spark.read.format("delta").load(articles_path)

joined_df = (
    cluster_df
    .join(articles_df, on="bronze_hash", how="left")
)

joined_df.select("bronze_hash", "cluster_id", "clean_text").show(5, truncate=False)
# Out:
# +--------------------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |bronze_hash         |cluster_id|clean_text                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# +--------------------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |-1889541934639726581|1         |Le parquet dément les allégations de grève de la faim de détenus sénégalais Le procureur du Roi près le Tribunal de première instance de Rabat a démenti les informations relayées par une agence de presse étrangère faisant état d’une prétendue grève de la faim observée par des ressortissants sénégalais détenus à la suite des actes de hooliganisme survenus lors de la finale de la Coupe d’Afrique des nations. [...] ONLY AVAILABLE IN PAID PLANS|
# |-1802607308808159383|15        |Trump's lesson from Minneapolis: From the Politics Desk In today’s edition, we have the top lines from President Donald Trump’s interview with “NBC Nightly News” anchor Tom Llamas. This is the online version of From the Politics Desk, a daily newsletter that brings you the NBC News Politics teams latest reporting and analysis from the White House, Capitol Hill and the campaign … [+5167 chars]                                                                     |
# |-7957235805070414591|14        |Emanuela Orlandi, convocati Dolores Brugnoli e Armando Palmegiani. Il mistero sulla BMW e le anomalie procedurali: cosa non torna Oggi, giovedì 5 febbraio, alle ore 13:30, la Commissione bicamerale d'inchiesta sulle scomparse di Emanuela Orlandi e Mirella Gregori torna a riunirsi per una seduta cruciale. Sotto i... ONLY AVAILABLE IN PAID PLANS                                                                                                                      |
# |754431215262548956  |18        |Manderson man on trial after for fire that killed one, injured another His defense attorney said there was a fire, but, "That doesn't make Reno guilty." ...                                                                                                                                                                                                                                                                                                                    |
# |-5991696855120567499|6         |Ausführen beliebiger Kommandos in phpunit9 (Fedora) Kostenlose Nachrichten, Web-Support und Foren rund um Linux, OpenSource und Freie Software. Angebote wie News, Berichte, Workshops, Tipps, Links und Kalender. --------------------------------------------------------------------------------Fedora Update NotificationFEDORA-2026-8d8a292bba2026-02-05 00:57:20.049043+00:00---------------------------------------… [+2808 chars]                                       |
# +--------------------+----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import lower, regexp_replace, col

df_clean = joined_df.withColumn(
    "text_processed",
    lower(regexp_replace(col("clean_text"), "[^a-zA-Z0-9\\s]", ""))
)

# %%
pdf = df_clean.select(
    "cluster_id",
    "text_processed"
).toPandas()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

cluster_keywords = {}

for cid in pdf["cluster_id"].unique():

    texts = pdf[pdf["cluster_id"] == cid]["text_processed"]

    if len(texts) < 3:
        cluster_keywords[cid] = []
        continue

    vectorizer = TfidfVectorizer(
        stop_words="english",
        max_features=50
    )

    X = vectorizer.fit_transform(texts)

    scores = X.mean(axis=0).A1
    terms = vectorizer.get_feature_names_out()

    top_idx = scores.argsort()[-10:][::-1]

    keywords = [terms[i] for i in top_idx]

    cluster_keywords[cid] = keywords

# %%
cluster_labels = {
    cid: ", ".join(words[:3])
    for cid, words in cluster_keywords.items()
}

# %%
import pandas as pd

label_pdf = pd.DataFrame({
    "cluster_id": list(cluster_labels.keys()),
    "cluster_label": list(cluster_labels.values()),
    "top_keywords": [
        ", ".join(cluster_keywords[cid])
        for cid in cluster_labels.keys()
    ]
})

label_spark_df = spark.createDataFrame(label_pdf)

# %%
final_df = joined_df.join(
    label_spark_df,
    on="cluster_id",
    how="left"
)

# %%
from delta.tables import DeltaTable

ml_cluster_labeled_path = "../../sanewsstorage/ml/clusters_labeled"

if DeltaTable.isDeltaTable(spark, ml_cluster_labeled_path):

    delta_table = DeltaTable.forPath(
        spark,
        ml_cluster_labeled_path
    )

    (
        delta_table.alias("t")
        .merge(
            final_df.alias("s"),
            "t.bronze_hash = s.bronze_hash"
        )
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        final_df.write
        .format("delta")
        .mode("overwrite")
        .save(ml_cluster_labeled_path)
    )

# %%
final_df.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+-----------+--------------------+-------------------+---------+-------------------+----------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+
# |cluster_id|         bronze_hash|          article_id|               title|         description|             content|       published_at|language|                 url|   keywords|          categories|            creator|source_id|        source_name|ingestion_source|          clean_text|language_detected|language_final|            entities|           embedding| entities_normalized|     topic|  subtopic|       cluster_label|        top_keywords|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+-----------+--------------------+-------------------+---------+-------------------+----------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+
# |        14|-7957235805070414591|96662171249ca6719...|Emanuela Orlandi,...|Oggi, giovedì 5 ...|ONLY AVAILABLE IN...|2026-02-05 12:08:25| italian|https://www.leggo...|   [italia]|    [top, lifestyle]|    [redazione web]|    leggo|           Leggo.it|        newsdata|Emanuela Orlandi,...|               it|       italian|[{Emanuela Orland...|[0.11244103, 0.12...|[{Emanuela Orland...|Technology|Technology|available, plans,...|available, plans,...|
# |         6|-5991696855120567499|https://www.pro-l...|Ausführen beliebi...|Kostenlose Nachri...|-----------------...|2026-02-05 11:42:25|    NULL|https://www.pro-l...|       NULL|                NULL|             [NULL]|     NULL|          Pro-Linux|         newsapi|Ausführen beliebi...|               de|            de|[{phpunit9, MISC}...|[-0.2507997, -0.1...|[{phpunit9, MISC}...|Technology|Technology|    chars, news, new|chars, news, new,...|
# |         1|-1889541934639726581|db14b35f392da82dd...|Le parquet démen...|Le procureur du R...|ONLY AVAILABLE IN...|2026-02-07 12:05:37|  french|https://lnt.ma/?p...|       NULL|[entertainment, top]|              [lnt]|   lnt_ma|La Nouvelle Tribune|        newsdata|Le parquet démen...|               fr|        french|[{grève, MISC}, ...|[-0.21145973, 0.2...|[{grève, MISC}, ...|Technology|Technology|available, plans,...|available, plans,...|
# |         0| 6908858088476876150|98ea2835a8c9dddfd...|Lahore 1947 relea...|Aamir Khan Produc...|ONLY AVAILABLE IN...|2026-02-09 12:07:00| english|https://www.news9...|[bollywood]|     [entertainment]|    [vijaya mishra]|news9live|          News9live|        newsdata|Lahore 1947 relea...|               en|       english|[{Independence, M...|[-0.13628091, 0.0...|[{Independence, M...|Technology|Technology|2026, available, ...|2026, available, ...|
# |        15|-1802607308808159383|https://www.nbcne...|Trump's lesson fr...|In today’s editio...|This is the onlin...|2026-02-05 03:47:51|    NULL|https://www.nbcne...|       NULL|                NULL|[The Politics Desk]| nbc-news|           NBC News|         newsapi|Trump's lesson fr...|               en|            en|[{Trump, PER}, {M...|[-1.2368501E-4, 0...|[{Trump, PER}, {M...|Technology|Technology|trump, donald, pr...|trump, donald, pr...|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+-----------+--------------------+-------------------+---------+-------------------+----------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+--------------------+--------------------+
# only showing top 5 rows
