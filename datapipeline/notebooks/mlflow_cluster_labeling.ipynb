# %%
import sys
import os

project_root = os.path.abspath("../..")
if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from datapipeline.utils.spark_session import get_spark_session
spark = get_spark_session("ML_Clustering")

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from delta.tables import DeltaTable

# %%
ml_cluster_path = os.path.join(project_root, "sanewsstorage/ml/clusters")
articles_path   = os.path.join(project_root, "sanewsstorage/gold/articles_final")
ml_cluster_labeled_path = os.path.join(project_root, "sanewsstorage/ml/clusters_labeled")

# %%
cluster_df  = spark.read.format("delta").load(ml_cluster_path)
articles_df = spark.read.format("delta").load(articles_path)

joined_df = (
    cluster_df
    .join(
        articles_df.select("bronze_hash", "entities_normalized"),
        on="bronze_hash",
        how="left"
    )
)

# %%
entities_df = (
    joined_df
    .filter(F.size("entities_normalized") > 0)
    .withColumn("entity", F.explode("entities_normalized"))
    .select(
        "cluster_id",
        F.col("entity.entity").alias("entity_name"),
        F.col("entity.label").alias("entity_label")
    )
    .filter(F.col("entity_name").isNotNull())
)

# %%
valid_labels = ["PER", "ORG", "GPE", "LOC", "EVENT"]

entities_df = entities_df.filter(F.col("entity_label").isin(valid_labels))

# %%
cluster_entity_freq = (
    entities_df
    .groupBy("cluster_id", "entity_name")
    .count()
    .withColumnRenamed("count", "cluster_freq")
)

# %%
global_entity_freq = (
    entities_df
    .groupBy("entity_name")
    .count()
    .withColumnRenamed("count", "global_freq")
)

# %%
scored_entities = (
    cluster_entity_freq
    .join(global_entity_freq, "entity_name")
    .withColumn(
        "score",
        F.col("cluster_freq") / F.col("global_freq")
    )
)

# %%
window_spec = Window.partitionBy("cluster_id").orderBy(F.desc("score"))

ranked_entities = (
    scored_entities
    .withColumn("rank", F.row_number().over(window_spec))
    .filter(F.col("rank") <= 5)
)

# %%
cluster_labels = (
    ranked_entities
    .groupBy("cluster_id")
    .agg(
        F.collect_list("entity_name").alias("top_entities")
    )
    .withColumn(
        "cluster_label",
        F.concat_ws(" ",
            F.expr("slice(top_entities, 1, 3)")
        )
    )
    .withColumn(
        "top_keywords",
        F.concat_ws(", ", F.col("top_entities"))
    )
)

# %%
cluster_labels = cluster_labels.select(
        "cluster_id",
        "cluster_label",
        "top_keywords"
)

# %%
if DeltaTable.isDeltaTable(spark, ml_cluster_labeled_path):

    delta_table = DeltaTable.forPath(
        spark,
        ml_cluster_labeled_path
    )

    (
        delta_table.alias("t")
        .merge(
            cluster_labels.alias("s"),
            "t.cluster_id = s.cluster_id"
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        cluster_labels.write
        .format("delta")
        .mode("overwrite")
        .save(ml_cluster_labeled_path)
    )

# %%
cluster_labels.show(10, truncate=False)
# Out:
# +----------+--------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...

# %%
spark.stop()
