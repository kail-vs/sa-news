# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TRANSFORMERS_NO_TORCHVISION"] = "1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
from datapipeline.utils.spark_session import get_spark_session

spark = get_spark_session("Gold_NER_Embedding")
spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "true")
spark.conf.set("spark.sql.parquet.enableVectorizedReader", "false")

# %%
gold_lang_path = "../../sanewsstorage/gold/articles_lang"

gold_df = spark.read.format("delta").load(gold_lang_path)

# %%
gold_df = gold_df.repartition(4)

# %%
import pandas as pd
import spacy

from pyspark.sql.functions import pandas_udf, col
from pyspark.sql.types import ArrayType, StructType, StructField, StringType

# %%
ner_schema = ArrayType(
    StructType([
        StructField("entity", StringType(), True),
        StructField("label", StringType(), True)
    ])
)

# %%
@pandas_udf(ner_schema)
def ner_udf(texts: pd.Series) -> pd.Series:

    nlp = spacy.load("xx_ent_wiki_sm")

    results = []

    for text in texts:

        if text is None or text.strip() == "":
            results.append([])
            continue

        doc = nlp(text)

        ents = [
            (ent.text, ent.label_)
            for ent in doc.ents
        ]

        results.append(ents)

    return pd.Series(results)

# %%
gold_df = gold_df.withColumn(
    "entities",
    ner_udf(col("clean_text"))
)

# %%
from sentence_transformers import SentenceTransformer
from pyspark.sql.types import ArrayType, FloatType

# %%
embedding_schema = ArrayType(FloatType())

# %%
@pandas_udf(embedding_schema)
def embedding_udf(texts: pd.Series) -> pd.Series:

    model = SentenceTransformer(
        "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    )

    text_list = texts.fillna("").tolist()

    vectors = model.encode(
        text_list,
        batch_size=32,
        show_progress_bar=False
    )

    return pd.Series(
        [vec.tolist() for vec in vectors]
    )

# %%
gold_df = gold_df.withColumn(
    "embedding",
    embedding_udf(col("clean_text"))
)

# %%
gold_df.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+
# |          article_id|               title|         description|             content|       published_at|language|                 url|            keywords|          categories|             creator|           source_id|        source_name|ingestion_source|         bronze_hash|          clean_text|language_detected|language_final|            entities|           embedding|
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+
# |db14b35f392da82dd...|Le parquet démen...|Le procureur du R...|ONLY AVAILABLE IN...|2026-02-07 12:05:37|  french|https://lnt.ma/?p...|                NULL|[entertainment, top]|               [lnt]|              lnt_ma|La Nouvelle Tribune|        newsdata|-1889541934639726581|Le parquet démen...|               fr|        french|[{grève, MISC}, ...|[-0.21145982, 0.2...|
# |https://www.nbcne...|Trump's lesson fr...|In today’s editio...|This is the onlin...|2026-02-05 03:47:51|    NULL|https://www.nbcne...|                NULL|                NULL| [The Politics Desk]|            nbc-news|           NBC News|         newsapi|-1802607308808159383|Trump's lesson fr...|               en|            en|[{Trump, PER}, {M...|[-1.2367725E-4, 0...|
# |96662171249ca6719...|Emanuela Orlandi,...|Oggi, giovedì 5 ...|ONLY AVAILABLE IN...|2026-02-05 12:08:25| italian|https://www.leggo...|            [italia]|    [top, lifestyle]|     [redazione web]|               leggo|           Leggo.it|        newsdata|-7957235805070414591|Emanuela Orlandi,...|               it|       italian|[{Emanuela Orland...|[0.112441055, 0.1...|
# |cd12626c-dd95-4be...|Manderson man on ...|His defense attor...|                 ...|2026-02-04 01:15:00|      en|https://rapidcity...|[Available on pai...|[Available on pai...|[SHALOM BAER GEE ...|Available on paid...| Rapid City Journal|     newsdatahub|  754431215262548956|Manderson man on ...|               en|            en|[{Manderson, PER}...|[-0.22888112, 0.3...|
# |https://www.pro-l...|Ausführen beliebi...|Kostenlose Nachri...|-----------------...|2026-02-05 11:42:25|    NULL|https://www.pro-l...|                NULL|                NULL|              [NULL]|                NULL|          Pro-Linux|         newsapi|-5991696855120567499|Ausführen beliebi...|               de|            de|[{phpunit9, MISC}...|[-0.2507997, -0.1...|
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+
# only showing top 5 rows

# %%
gold_df.count()
# Out:
# 27663

# %%
from delta.tables import DeltaTable

gold_ml_path = "../../sanewsstorage/gold/articles_enriched"

if DeltaTable.isDeltaTable(spark, gold_ml_path):

    delta_table = DeltaTable.forPath(spark, gold_ml_path)

    (
        delta_table.alias("t")
        .merge(
            gold_df.alias("s"),
            "t.bronze_hash = s.bronze_hash"
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        gold_df.write
        .format("delta")
        .mode("overwrite")
        .save(gold_ml_path)
    )
