# %%
import sys
import os

project_root = os.path.abspath("../..")
if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
from datapipeline.utils.spark_session import get_spark_session
spark = get_spark_session("Gold_NER_Embedding")

spark.conf.set("spark.sql.shuffle.partitions", "32")

# %%
spark.conf.set("spark.sql.shuffle.partitions", "32")

# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *
from delta.tables import DeltaTable
from pyspark.sql.functions import pandas_udf
import pandas as pd
from sentence_transformers import SentenceTransformer
import spacy

# %%
gold_lang_path = "../../sanewsstorage/gold/articles_lang"
gold_ml_path = "../../sanewsstorage/gold/articles_enriched"

source_df = spark.read.format("delta").load(gold_lang_path)

# %%
if DeltaTable.isDeltaTable(spark, gold_ml_path):
    existing_df = spark.read.format("delta").load(gold_ml_path)
    source_df = source_df.join(
        existing_df.select("bronze_hash"),
        on="bronze_hash",
        how="left_anti"
    )

if source_df.rdd.isEmpty():
    print("No new records to process.")
    spark.stop()
    exit()

source_df = source_df.repartition(
    min(32, spark.sparkContext.defaultParallelism)
)

# %%
output_schema = StructType([
    StructField(
        "entities",
        ArrayType(
            StructType([
                StructField("entity", StringType()),
                StructField("label", StringType())
            ])
        )
    ),
    StructField(
        "embedding",
        ArrayType(FloatType())
    )
])

# %%
embed_model = SentenceTransformer(
            "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
        )

nlp = spacy.load("xx_ent_wiki_sm")

# %%
@pandas_udf(output_schema)
def enrich_udf(texts: pd.Series) -> pd.DataFrame:
    if not hasattr(enrich_udf, "nlp"):
        import spacy
        enrich_udf.nlp = spacy.load("xx_ent_wiki_sm")

    if not hasattr(enrich_udf, "embed_model"):
        from sentence_transformers import SentenceTransformer
        enrich_udf.embed_model = SentenceTransformer(
            "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
        )

    nlp = enrich_udf.nlp
    embed_model = enrich_udf.embed_model

    clean_texts = texts.fillna("").tolist()

    vectors = embed_model.encode(
        clean_texts,
        batch_size=64,
        show_progress_bar=False
    )

    ner_results = []
    for doc in nlp.pipe(clean_texts, batch_size=64):
        ents = [(ent.text, ent.label_) for ent in doc.ents]
        ner_results.append(ents)

    return pd.DataFrame({
        "entities": ner_results,
        "embedding": [vec.tolist() for vec in vectors]
    })

# %%
enriched_df = source_df.withColumn(
    "enriched",
    enrich_udf(F.col("clean_text"))
)

final_df = (
    enriched_df
    .withColumn("entities", F.col("enriched.entities"))
    .withColumn("embedding", F.col("enriched.embedding"))
    .drop("enriched")
)

# %%
final_df.show(50)
# Out:
# +--------------------+--------------------+-------------------------------------+---------------------------------+--------------------+-------------------+---------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+----------------+-------------------------------------+-----------------+--------------+-----------------------------------+--------------------+
# |         bronze_hash|          article_id|                                title|                      description|             content|       published_at| language|                 url|            keywords|          categories|             creator|         source_id|         source_name|ingestion_source|                           clean_text|language_detected|language_final|                           entities|           embedding|
# ...

# %%
if DeltaTable.isDeltaTable(spark, gold_ml_path):

    delta_table = DeltaTable.forPath(spark, gold_ml_path)

    (
        delta_table.alias("t")
        .merge(
            final_df.alias("s"),
            "t.bronze_hash = s.bronze_hash"
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        final_df.write
        .format("delta")
        .mode("overwrite")
        .save(gold_ml_path)
    )

# %%
spark.stop()
