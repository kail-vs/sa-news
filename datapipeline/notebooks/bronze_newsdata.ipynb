# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from datapipeline.utils.spark_session import get_spark_session

spark = get_spark_session("Bronze_NewsData")
spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "true")
spark.conf.set("spark.sql.parquet.enableVectorizedReader", "false")

# %%
from pyspark.sql.functions import col, xxhash64
from pyspark.sql.types import StringType, IntegerType, DoubleType, LongType, FloatType, BooleanType

newsdata_data_path = "../../sanewsstorage/main/newsdata"

newsdata_df = (
    spark.read
         .option("recursiveFileLookup", "true")
         .parquet(newsdata_data_path)
)

for c in newsdata_df.columns:
    if "." in c:
        newsdata_df = newsdata_df.withColumnRenamed(c, c.replace(".", "_"))

primitive_types = (IntegerType, DoubleType, LongType, FloatType, BooleanType)

newsdata_df = newsdata_df.select([
    col(c).cast("string").alias(c)
    if isinstance(newsdata_df.schema[c].dataType, primitive_types)
    else col(c)
    for c in newsdata_df.columns
])

newsdata_df = newsdata_df.withColumn(
    "hash",
    xxhash64(*[col(c) for c in newsdata_df.columns])
)

newsdata_df.printSchema()
newsdata_df.show(20)
# Out:
# root
#  |-- article_id: string (nullable = true)
#  |-- link: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- content: string (nullable = true)
#  |-- keywords: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- creator: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- language: string (nullable = true)
#  |-- country: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- datatype: string (nullable = true)
#  |-- pubDate: string (nullable = true)
#  |-- pubDateTZ: string (nullable = true)
#  |-- fetched_at: string (nullable = true)
#  |-- image_url: string (nullable = true)
#  |-- video_url: string (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- source_name: string (nullable = true)
#  |-- source_priority: string (nullable = true)
#  |-- source_url: string (nullable = true)
#  |-- source_icon: string (nullable = true)
#  |-- sentiment: string (nullable = true)
#  |-- sentiment_stats: string (nullable = true)
#  |-- ai_tag: string (nullable = true)
#  |-- ai_region: string (nullable = true)
#  |-- ai_org: string (nullable = true)
#  |-- ai_summary: string (nullable = true)
#  |-- duplicate: string (nullable = true)
#  |-- hash: long (nullable = false)
#
# +--------------------+--------------------+---------------------------+--------------------------+--------------------+--------------------+-----------------------------+---------+--------------------+------------------+--------+-------------------+---------+-------------------+--------------------+---------+---------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |          article_id|                link|                      title|               description|             content|            keywords|                      creator| language|             country|          category|datatype|            pubDate|pubDateTZ|         fetched_at|           image_url|video_url|      source_id|         source_name|source_priority|          source_url|         source_icon|           sentiment|     sentiment_stats|              ai_tag|           ai_region|              ai_org|          ai_summary|duplicate|                hash|
# +--------------------+--------------------+---------------------------+--------------------------+--------------------+--------------------+-----------------------------+---------+--------------------+------------------+--------+-------------------+---------+-------------------+--------------------+---------+---------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |6e16b299ed5db52e7...|https://www.thepo...|       Portugisiska anse...|      Språket är inte...|ONLY AVAILABLE IN...|                NULL|                         NULL|  swedish|          [portugal]|             [top]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:39:51|https://d1mnxluw9...|     NULL|theportugalnews|   The Portugal News|         103133|https://www.thepo...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-5460607462645468593|
# |b1d488835a359ee2e...|https://www.laven...|       Lutte contre le f...|      La campagne de di...|ONLY AVAILABLE IN...|              [mons]|            [emeline berlier]|   french|           [belgium]|           [other]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:36:43|https://www.laven...|     NULL|    lavenir_net|         Lavenir Net|          32741|https://www.laven...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 1479796490748388396|
# |296f1d51b25ace065...|https://www.sport...|집에서 비둘기르...|[스타뉴스 | 안유...|ONLY AVAILABLE IN...|              [엔터]|                 [안윤지기자]|   korean|       [south korea]|          [sports]|    news|2026-02-09 12:03:00|      UTC|2026-02-09
|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:31:20|https://cdn-image...|     NULL|        express|    Daily Express Us|           1139|https://www.the-e...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-5698308550195923921|
# |b1aed4919a5cfdcc5...|https://www.india...|       कानपुर लेम्बोर्गि...|      Shivam Mishra Kan...|ONLY AVAILABLE IN...|[fir registered i...|         [vishal pratap si...|    hindi|             [india]|   [top, breaking]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:33:06|https://resize.kh...|     NULL|        indiatv|            India Tv|           8882|https://www.india...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 8365131148613569209|
# |2537489af0eb46d97...|https://www.vijes...|       Goran Milić se j...|      Poznati hrvatski ...|ONLY AVAILABLE IN...|             [video]|                 [screenshot]|  bosnian|[bosnia and herze...|             [top]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:09:19|https://www.vijes...|     NULL|     vijesti_ba|           Vijestiba|          99334|  https://vijesti.ba|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 7859964827299612149|
# |fe05da3143d1ed617...|https://www.khan....|다카이치 승리에....| “대만 발언 철...|ONLY AVAILABLE IN...|              [일본]|[베이징 | 박은하 특파원 eu...|   korean|       [south korea]|             [top]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:06:03|https://img.khan....|     NULL|           khan|            경향신문|          27808|https://www.khan....|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-7968290440602120741|
# |02bfc162f3bca18e4...|https://nv.ua/ukr...|       Більше не чужий....|      Популярність авок...|ONLY AVAILABLE IN...|          [food/їжа]|                         NULL|ukrainian|           [ukraine]|             [top]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:09:29|https://static.nv...|     NULL|          nv_ua|                  Nv|         106462|       https://nv.ua|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| -301618364398211450|
# |49abb170344820d8d...|https://www.irish...|       Escort accused in...|      She and three Bra...|ONLY AVAILABLE IN...|[#courts, tom tuite]|          [irishexaminer.com]|  english|           [ireland]|      [crime, top]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:35:15|https://www.irish...|     NULL|  irishexaminer|      Irish Examiner|          23120|https://www.irish...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-7206474240804714939|
# |f3451f16803a45d8b...|https://www.aamul...|       Nyt vietetään y...|      Ystävällisten v...|ONLY AVAILABLE IN...|[ihmissuhteet, ku...|                  [aamulehti]|  finnish|           [finland]|  [top, lifestyle]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:16:52|https://images.sa...|     NULL|   aamulehti_fi|           Aamulehti|         834754|https://www.aamul...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 2289680863795060651|
# |115e41ce78074363b...|https://www.gamer...|       Siste glimt av Th...|      Helt siden den fø...|ONLY AVAILABLE IN...|[kino, the mandal...|         [ben@gamereactor....|norwegian|            [norway]|   [entertainment]|    news|2026-02-09 12:03:00|      UTC|2026-02-09 12:23:19|https://www.gamer...|     NULL|    gamereactor|         Gamereactor|        6096572|https://www.gamer...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 5832380290648226641|
# +--------------------+--------------------+---------------------------+--------------------------+--------------------+--------------------+-----------------------------+---------+--------------------+------------------+--------+-------------------+---------+-------------------+--------------------+---------+---------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# only showing top 20 rows

# %%
from delta.tables import DeltaTable
import os

bronze_path = "../../sanewsstorage/bronze/deltatables/newsdata_delta"

if DeltaTable.isDeltaTable(spark, bronze_path):

    delta_table = DeltaTable.forPath(spark, bronze_path)

    (
        delta_table.alias("t")
        .merge(
            newsdata_df.alias("s"),
            "t.hash = s.hash"
        )
        .whenNotMatchedInsertAll()
        .execute()
    )

else:
    (
        newsdata_df.write
          .format("delta")
          .mode("overwrite")
          .save(bronze_path)
    )

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(spark, bronze_path)
df = delta_table.toDF()
df.show(5)

files = delta_table.toDF().inputFiles
print(files)
# Out:
# +--------------------+--------------------+-------------------------------+--------------------------------+--------------------+--------------------+--------------------+--------+----------------+--------------------+--------+-------------------+---------+-------------------+--------------------+---------+--------------------+--------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |          article_id|                link|                          title|                     description|             content|            keywords|             creator|language|         country|            category|datatype|            pubDate|pubDateTZ|         fetched_at|           image_url|video_url|           source_id|   source_name|source_priority|          source_url|         source_icon|           sentiment|     sentiment_stats|              ai_tag|           ai_region|              ai_org|          ai_summary|duplicate|                hash|
# +--------------------+--------------------+-------------------------------+--------------------------------+--------------------+--------------------+--------------------+--------+----------------+--------------------+--------+-------------------+---------+-------------------+--------------------+---------+--------------------+--------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |af052a4bdf57a48f3...|https://www.mirag...|           Dame Carol Black'...|            The Secretary of ...|ONLY AVAILABLE IN...|                NULL|       [mirage news]| english|     [australia]|         [education]|    news|2026-02-16 12:06:19|      UTC|2026-02-16 12:36:49|https://www.gov.u...|     NULL|          miragenews|   Mirage News|          38838|https://www.mirag...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-4690384357412638291|
# |f6cb088cbb87de571...|https://news.yaho...|住宅出火2人死傷「灯油」まかれた|16日午前4時15分ごろ、広島県...|ONLY AVAILABLE IN...|                NULL|          [共同通信]|japanese|         [japan]|[sports, top, lif...|    news|2026-02-16 12:06:19|      UTC|2026-02-16 12:30:48|https://news-pctr...|     NULL|            yahoo_jp|   Yahoo Japan|            449|https://news.yaho...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 4548702943038784695|
# |c32cb269328650ff5...|https://www.white...|           Road in West Cumb...|            A ROAD will be cl...|ONLY AVAILABLE IN...|[content-level:1,...|[brandon.mawson@n...| english|[united kingdom]|        [crime, top]|    news|2026-02-16 12:06:19|      UTC|2026-02-16 12:17:31|https://www.white...|     NULL|whitehavennews_co_uk|Whitehavennews|        1266292|https://www.white...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 8544180681669826576|
# |a92a85058adb931ff...|https://www.babne...|           قضية جيفري إبستي...|            شكّل اعتقال جيفري...|ONLY AVAILABLE IN...|[قضية جيفري إبستي...|            [babnet]|  arabic|       [tunisia]|    [top, lifestyle]|    news|2026-02-16 12:06:19|      UTC|2026-02-16 12:44:22|https://www.babne...|     NULL|              babnet|Babnet Tunisie|         456187|https://www.babne...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-5274582897686989328|
# |9e132c0c8a6f8e36e...|https://www.eldeb...|           Así se ha transf...|                            NULL|ONLY AVAILABLE IN...|           [ciencia]|[redacción el deb...| spanish|         [spain]|       [environment]|    news|2026-02-16 12:06:18|      UTC|2026-02-16 12:39:02|https://imagenes....|     NULL|            eldebate|     El Debate|          60292|https://www.eldeb...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 4242444935953129088|
# +--------------------+--------------------+-------------------------------+--------------------------------+--------------------+--------------------+--------------------+--------+----------------+--------------------+--------+-------------------+---------+-------------------+--------------------+---------+--------------------+--------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# only showing top 5 rows
#
# <bound method DataFrame.inputFiles of DataFrame[article_id: string, link: string, title: string, description: string, content: string, keywords: array<string>, creator: array<string>, language: string, country: array<string>, category: array<string>, datatype: string, pubDate: string, pubDateTZ: string, fetched_at: string, image_url: string, video_url: string, source_id: string, source_name: string, source_priority: string, source_url: string, source_icon: string, sentiment: string, sentiment_stats: string, ai_tag: string, ai_region: string, ai_org: string, ai_summary: string, duplicate: string, hash: bigint]>

# %%
spark.stop()
