# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from datapipeline.utils.spark_session import get_spark_session

spark = get_spark_session("Bronze_NewsData")

# %%
from pyspark.sql.functions import xxhash64, col

newsdata_data_path = "../../sanewsstorage/main/newsdata"

newsdata_df = (
    spark.read
         .option("recursiveFileLookup", "true")
         .parquet(newsdata_data_path)
)

newsdata_df.printSchema()

newsdata_df = newsdata_df.withColumn(
    "hash",
    xxhash64(*[col(f"`{c}`") for c in newsdata_df.columns])
)

newsdata_df.show(20)
# Out:
# root
#  |-- article_id: string (nullable = true)
#  |-- link: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- content: string (nullable = true)
#  |-- keywords: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- creator: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- language: string (nullable = true)
#  |-- country: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- datatype: string (nullable = true)
#  |-- pubDate: string (nullable = true)
#  |-- pubDateTZ: string (nullable = true)
#  |-- fetched_at: string (nullable = true)
#  |-- image_url: string (nullable = true)
#  |-- video_url: integer (nullable = true)
#  |-- source_id: string (nullable = true)
#  |-- source_name: string (nullable = true)
#  |-- source_priority: long (nullable = true)
#  |-- source_url: string (nullable = true)
#  |-- source_icon: string (nullable = true)
#  |-- sentiment: string (nullable = true)
#  |-- sentiment_stats: string (nullable = true)
#  |-- ai_tag: string (nullable = true)
#  |-- ai_region: string (nullable = true)
#  |-- ai_org: string (nullable = true)
#  |-- ai_summary: string (nullable = true)
#  |-- duplicate: boolean (nullable = true)
#
# +--------------------+--------------------+-------------------------------------+----------------------------------+--------------------+--------------------------------+--------------------+----------+------------+----------------+--------+-------------------+---------+-------------------+--------------------+---------+----------------+-----------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |          article_id|                link|                                title|                       description|             content|                        keywords|             creator|  language|     country|        category|datatype|            pubDate|pubDateTZ|         fetched_at|           image_url|video_url|       source_id|            source_name|source_priority|          source_url|         source_icon|           sentiment|     sentiment_stats|              ai_tag|           ai_region|              ai_org|          ai_summary|duplicate|                hash|
# +--------------------+--------------------+-------------------------------------+----------------------------------+--------------------+--------------------------------+--------------------+----------+------------+----------------+--------+-------------------+---------+-------------------+--------------------+---------+----------------+-----------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |8db76c0f5eecfea97...|https://www.repub...|                 La lettera: "Ora ...|                              NULL|ONLY AVAILABLE IN...|                      [politica]|[repubblicawww@re...|   italian|     [italy]|      [politics]|    news|2026-02-07 12:06:27|      UTC|2026-02-07 12:35:14|https://www.repst...|     NULL|      repubblica|          La Repubblica|          22834|https://www.repub...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 7796895871399181162|
# |0a9a27f2175af3d8d...|https://www.trans...|                 NEOM SC leiht Ray...|              Das französische...|ONLY AVAILABLE IN...|            [rc straßburg als...|[redaktion@transf...|    german|   [austria]|[top, lifestyle]|    news|2026-02-07 12:06:26|      UTC|2026-02-07 12:20:05|https://tmssl.aka...|     NULL|transfermarkt_at|      Fußball-transfers|        6725552|https://www.trans...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-5505037689500700740|
# |bcc8b6e13ed871670...|https://www.nieuw...|                 Legendarische caf...|              Oedelem neemt afs...|ONLY AVAILABLE IN...|                    [binnenland]|      [arne  franck]|     dutch|   [belgium]|      [domestic]|    news|2026-02-07 12:06:25|      UTC|2026-02-07 12:33:57|https://prod-img....|     NULL|   nieuwsblad_be|          Nieuwsblad Be|          13256|https://www.nieuw...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-7247031415708828008|
# |a0f722204a03fa5b5...|https://www.rbc.r...|                 Экс-министр культ...|              Бывший французск...|ONLY AVAILABLE IN...|                      [политика]|  [полина мартынова]|   russian|    [russia]|           [top]|    news|2026-02-07 12:06:25|      UTC|2026-02-07 12:33:47|https://s0.rbk.ru...|     NULL|             rbc|                    Rbc|          12816|  https://www.rbc.ru|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|
------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# only showing top 20 rows

# %%
from delta.tables import DeltaTable
import os

bronze_path = "../../sanewsstorage/bronze/deltatables/newsdata_delta"

if DeltaTable.isDeltaTable(spark, bronze_path):

    delta_table = DeltaTable.forPath(spark, bronze_path)

    (
        delta_table.alias("t")
        .merge(
            newsdata_df.alias("s"),
            "t.hash = s.hash"
        )
        .whenNotMatchedInsertAll()
        .execute()
    )

else:
    (
        newsdata_df.write
          .format("delta")
          .mode("overwrite")
          .save(bronze_path)
    )

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(spark, bronze_path)
df = delta_table.toDF()
df.show(5)

files = delta_table.toDF().inputFiles
print(files)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+---------------+--------+-------------------+---------+-------------------+--------------------+---------+------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |          article_id|                link|               title|         description|             content|            keywords|             creator|language|             country|       category|datatype|            pubDate|pubDateTZ|         fetched_at|           image_url|video_url|         source_id|         source_name|source_priority|          source_url|         source_icon|           sentiment|     sentiment_stats|              ai_tag|           ai_region|              ai_org|          ai_summary|duplicate|                hash|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+---------------+--------+-------------------+---------+-------------------+--------------------+---------+------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# |535bb1742b1dcbd4f...|https://bengali.n...|Electric Bill Sav...|Electric Bill Sav...|ONLY AVAILABLE IN...|         [প্রযুক্তি]|    [shubhagata dey]| bengali|             [india]|   [technology]|    news|2026-02-05 12:07:08|      UTC|2026-02-05 12:32:59|https://images.ne...|     NULL|    bengali_news18|     Bengali News 18|           4964|https://bengali.n...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false|-2729877914981235816|
# |0f8c91e6ae12b7fd2...|https://www.vetog...|لماذا وافق ترامب ...|الملفات مفتوحة. و...|ONLY AVAILABLE IN...|                NULL|[فيتو | محمد حسن ...|  arabic|             [egypt]|          [top]|    news|2026-02-05 12:07:08|      UTC|2026-02-05 12:07:08|https://www.vetog...|     NULL|          vetogate|                فيتو|          59162|https://www.vetog...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 4598469544627568625|
# |7fc250fbdf2050d55...|https://rg.ru/202...|Нарышкин: РФ посл...|Директор СВР Серг...|ONLY AVAILABLE IN...|                NULL|                NULL| russian|            [russia]|          [top]|    news|2026-02-05 12:07:08|      UTC|2026-02-05 12:31:16|                NULL|     NULL|             rg_ru|   Российская Газета|           3082|   https://www.rg.ru|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 6942835748815302555|
# |c7a066a100475e118...|https://www.donca...|Vacancy for a liv...|A job vacancy for...|ONLY AVAILABLE IN...|      [news, people]| [stephanie bateman]| english|[united states of...|[top, business]|    news|2026-02-05 12:07:07|      UTC|2026-02-05 12:39:01|https://www.donca...|     NULL|doncasterfreepress|Doncaster Free Press|         116051|https://www.donca...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 1067919027747097496|
# |a789fba1fdadac57a...|https://www.watch...|Mission Wealth Ma...|Mission Wealth Ma...|ONLY AVAILABLE IN...|[investing, sec f...| [lindsey winhoffer]| english|[united states of...|     [business]|    news|2026-02-05 12:07:07|      UTC|2026-02-05 12:15:42|https://www.marke...|     NULL|     watchlistnews|     Watch List News|         927984|https://www.watch...|https://n.bytvi.c...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|ONLY AVAILABLE IN...|    false| 1666095041454649853|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+---------------+--------+-------------------+---------+-------------------+--------------------+---------+------------------+--------------------+---------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+--------------------+
# only showing top 5 rows
#
# <bound method DataFrame.inputFiles of DataFrame[article_id: string, link: string, title: string, description: string, content: string, keywords: array<string>, creator: array<string>, language: string, country: array<string>, category: array<string>, datatype: string, pubDate: string, pubDateTZ: string, fetched_at: string, image_url: string, video_url: int, source_id: string, source_name: string, source_priority: bigint, source_url: string, source_icon: string, sentiment: string, sentiment_stats: string, ai_tag: string, ai_region: string, ai_org: string, ai_summary: string, duplicate: boolean, hash: bigint]>

# %%
spark.stop()
