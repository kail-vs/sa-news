# %%
import sys
import os
from datetime import datetime, timedelta

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from datapipeline.utils.spark_session import get_spark_session
spark = get_spark_session("Analytics_Build_Layer")

# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from delta.tables import DeltaTable

# %%
gold_path = os.path.join(project_root, "sanewsstorage/gold/articles_enriched")

clusters_path = os.path.join(project_root, "sanewsstorage/ml/clusters")
clusters_labeled_path = os.path.join(project_root, "sanewsstorage/ml/clusters_labeled")
events_path = os.path.join(project_root, "sanewsstorage/ml/events")
event_lifecycle_path = os.path.join(project_root, "sanewsstorage/ml/event_lifecycle")

analytics_base = os.path.join(project_root, "sanewsstorage/analytics")

topic_daily_path = os.path.join(analytics_base, "topic_daily")
topic_summary_path = os.path.join(analytics_base, "topic_summary")
event_snapshot_path = os.path.join(analytics_base, "event_snapshot")
event_history_path = os.path.join(analytics_base, "event_history")
entity_snapshot_path = os.path.join(analytics_base, "entity_snapshot")
search_index_path = os.path.join(analytics_base, "search_index")

# %%
gold_df = spark.read.format("delta").load(gold_path)
clusters_df = spark.read.format("delta").load(clusters_path)
clusters_labeled_df = spark.read.format("delta").load(clusters_labeled_path)
events = spark.read.format("delta").load(events_path)
event_lifecycle = spark.read.format("delta").load(event_lifecycle_path)

# %%
window_7d = (
    Window
    .partitionBy("cluster_id")
    .orderBy("date")
    .rowsBetween(-6, 0)
)

# %%
topic_daily = (
    events
    .select(
        "cluster_id",
        "cluster_label",
        "date",
        "article_count",
        "z_score",
        "event_intensity",
        "is_event"
    )
    .withColumn("rolling_7d_avg", F.avg("article_count").over(window_7d))
    .withColumn(
        "momentum",
        F.col("article_count") - F.col("rolling_7d_avg")
    )
)

# %%
(
    topic_daily
    .write
    .format("delta")
    .mode("overwrite")
    .partitionBy("date")
    .save(topic_daily_path)
)

# %%
latest_date = events.agg(F.max("date")).collect()[0][0]

latest_daily = (
    events
    .filter(F.col("date") == latest_date)
)

latest_lifecycle = (
    event_lifecycle
    .orderBy(F.desc("end_date"))
    .dropDuplicates(["cluster_id"])
)

# %%
latest_daily_alias = latest_daily.alias("d")
latest_lifecycle_alias = latest_lifecycle.alias("l")

topic_summary = (
    latest_daily_alias
    .join(
        latest_lifecycle_alias,
        F.col("d.cluster_id") == F.col("l.cluster_id"),
        "left"
    )
    .select(
        F.col("d.cluster_id").alias("cluster_id"),
        F.col("d.cluster_label").alias("cluster_label"),
        F.col("d.article_count").alias("today_volume"),
        F.col("d.z_score"),
        F.col("d.event_intensity"),
        F.col("d.is_event"),
        F.col("l.duration_days"),
        F.col("l.peak_volume"),
        F.col("l.event_score_peak"),
        F.col("l.event_type")
    )
    .withColumn(
        "is_hot",
        F.when(
            (F.col("is_event") == 1) |
            (F.col("z_score") >= 2),
            1
        ).otherwise(0)
    )
)

(
    topic_summary
    .write
    .format("delta")
    .mode("overwrite")
    .save(topic_summary_path)
)

# %%
event_snapshot = (
    event_lifecycle
    .filter(F.col("end_date") >= F.date_sub(F.current_date(), 1))
    .withColumn(
        "event_stage",
        F.when(F.col("duration_days") == 1, "New")
         .when(F.col("duration_days") <= 3, "Growing")
         .otherwise("Mature")
    )
    .orderBy(F.desc("event_score_peak"))
)

(
    event_snapshot
    .write
    .format("delta")
    .mode("overwrite")
    .save(event_snapshot_path)
)

# %%
(
    event_lifecycle
    .write
    .format("delta")
    .mode("overwrite")
    .save(event_history_path)
)

# %%
entity_base = (
    gold_df
    .withColumn("date", F.to_date("published_at"))
    .withColumn("entity", F.explode("entities"))
    .select(
        "date",
        F.col("entity.entity").alias("entity_name"),
        F.col("entity.label").alias("entity_label")
    )
    .filter(F.col("entity_name").isNotNull())
)

# %%
entity_7d = (
    entity_base
    .filter(F.col("date") >= F.date_sub(F.current_date(), 7))
    .groupBy("entity_name", "entity_label")
    .count()
    .withColumnRenamed("count", "mentions_7d")
)

entity_24h = (
    entity_base
    .filter(F.col("date") >= F.date_sub(F.current_date(), 1))
    .groupBy("entity_name")
    .count()
    .withColumnRenamed("count", "mentions_24h")
)

# %%
entity_snapshot = (
    entity_7d
    .join(entity_24h, "entity_name", "left")
    .fillna(0)
    .withColumn(
        "growth_signal",
        F.when(F.col("mentions_7d") > 0,
               F.col("mentions_24h") / F.col("mentions_7d"))
         .otherwise(0)
    )
)

(
    entity_snapshot
    .write
    .format("delta")
    .mode("overwrite")
    .save(entity_snapshot_path)
)

# %%
search_index = (
    gold_df
    .select("bronze_hash", "title", "published_at", "url")
    .join(clusters_df, "bronze_hash", "left")
    .join(clusters_labeled_df, "cluster_id", "left")
)

# %%
if DeltaTable.isDeltaTable(spark, search_index_path):

    delta_table = DeltaTable.forPath(spark, search_index_path)

    (
        delta_table.alias("t")
        .merge(
            search_index.alias("s"),
            "t.bronze_hash = s.bronze_hash"
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:
    (
        search_index
        .write
        .format("delta")
        .mode("overwrite")
        .save(search_index_path)
    )

# %%
spark.stop()
