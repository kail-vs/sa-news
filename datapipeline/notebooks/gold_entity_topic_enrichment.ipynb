# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from datapipeline.utils.spark_session import get_spark_session

spark = get_spark_session("Gold_Entity_Topic")
spark.conf.set("spark.databricks.delta.schema.autoMerge.enabled", "true")

# %%
gold_enriched_path = "../../sanewsstorage/gold/articles_enriched"
gold_df = spark.read.format("delta").load(gold_enriched_path)

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StructType, StructField, StringType

# %%
ENTITY_MAP = {
    "U.S.": "United States",
    "US": "United States",
    "USA": "United States",
    "U.K.": "United Kingdom",
    "UK": "United Kingdom"
}

# %%
def normalize_entities(entities):
    if entities is None:
        return []

    normalized = []

    for ent in entities:
        text = ent["entity"]
        label = ent["label"]

        canonical = ENTITY_MAP.get(text, text)

        normalized.append({
            "entity": canonical,
            "label": label
        })

    return normalized

# %%
norm_schema = ArrayType(
    StructType([
        StructField("entity", StringType(), True),
        StructField("label", StringType(), True)
    ])
)

normalize_udf = udf(normalize_entities, norm_schema)

# %%
gold_df = gold_df.withColumn(
    "entities_normalized",
    normalize_udf("entities")
)

# %%
TOPIC_KEYWORDS = {
    "Politics": ["election", "government", "minister", "parliament"],
    "Finance": ["stock", "market", "investment", "bank"],
    "Technology": ["ai", "software", "tech", "startup"],
    "Sports": ["match", "tournament", "cricket", "football"],
    "Health": ["covid", "vaccine", "hospital", "health"]
}

# %%
def classify_topic(text):

    if text is None:
        return "Other"

    text_lower = text.lower()

    for topic, keywords in TOPIC_KEYWORDS.items():
        for kw in keywords:
            if kw in text_lower:
                return topic

    return "Other"

# %%
from pyspark.sql.types import StringType

topic_udf = udf(classify_topic, StringType())

gold_df = gold_df.withColumn(
    "topic",
    topic_udf("clean_text")
)

# %%
gold_df = gold_df.withColumn(
    "subtopic",
    topic_udf("clean_text")
)

# %%
gold_df.select(
    "topic",
    "entities_normalized"
).show(10, truncate=False)
# Out:
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |topic     |entities_normalized                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |Technology|[{Nashua, LOC}, {NH, LOC}, {NASHUA, ORG}, {N.H, ORG}, {WHDH, ORG}, {Nashua, LOC}, {New Hampshire, LOC}, {href="https://whdh.com/news/officials-praise-response-to-natural-gas-explosion-at-nas, MISC}, {NASHUA, ORG}, {N.H, ORG}, {WHDH, ORG}, {Nashua, LOC}, {New Hampshire, LOC}, {Monday afternoon, MISC}]                                                                                                                                                |
# |Other     |[{Super Bowl More, MISC}, {Super Bowl LX, ORG}, {Santa Clara, LOC}, {California, LOC}, {Santa Clara, LOC}, {California, LOC}, {Circling Levi's Stadium, LOC}, {Santa Clara, LOC}, {California, LOC}, {U.S. Customs, ORG}, {Border Protection, MISC}, {bird, PER}]                                                                                                                                                                                            |
# |Technology|[{InventHelp Inventor Develops Hands-Free Foot Washing Accessory, MISC}, {TLS-1055, MISC}, {PITTSBURGH, MISC}, {Feb, ORG}, {Hodgenville, LOC}, {Ky., LOC}, {FOOT, ORG}, {ONLY, ORG}]                                                                                                                                                                                                                                                                         |
# |Technology|[{Jennifer Lopez, PER}, {Ben Affleck, PER}, {Jennifer Garner, PER}, {Jennifer Garner, PER}, {Jennifer Lopez, PER}, {Garner, PER}, {Jennifer Garner, PER}, {Jennifer Lopez, PER}]                                                                                                                                                                                                                                                                             |
# |Technology|[{fit2work, MISC}, {Diagnose, PER}, {Leoben, LOC}, {Mürzzuschlag, LOC}, {BRUCK-MÜRZZUSCHLAG, MISC}, {LEOBEN, MISC}, {Kopf, LOC}, {Upgrade, MISC}]                                                                                                                                                                                                                                                                                                            |
# |Other     |[{Victor Wembanyama, PER}, {Nike GT Cut 4 “Warning Label” Comes With An Alien Charm Nike Basketball, MISC}, {NBA All-Star 2026, MISC}, {Nike GT Cut 4 “Warning Label, MISC}, {Spurs, ORG}, {Victor Wembanyama, PER}, {Sneaker News, MISC}, {Add todel.icio.us\n\n\nThe, MISC}, {Victor Wembanyama, PER}, {Ni… Nike Basketball, MISC}, {NBA All-Star 2026, MISC}, {Nike GT Cut 4 “Warning Label, MISC}, {Spurs, ORG}, {Victor Wembanyama, PER}, {Wemby, MISC}]|
# |Technology|[{Anson, PER}, {Avro, ORG}, {Wisconsin, LOC}, {Airs, MISC}, {Two, MISC}, {Underdog Pet Rescue, ORG}, {Wisconsin, LOC}, {Puppy Bowl, ORG}, {Anson, PER}, {Avro, ORG}, {Wisconsin, LOC}, {Puppy Bowl, ORG}, {Wisconsin, LOC}, {Anson, PER}, {Avro, ORG}, {Wisconsin, LOC}, {Airs, MISC}, {WisBusiness, PER}]                                                                                                                                                   |
# |Technology|[{NFL, ORG}, {Chiefs, ORG}, {Giants, ORG}, {How, MISC}, {NFL, ORG}, {NFL, ORG}, {Super Bowl 61, MISC}, {NFL, ORG}, {Chiefs, ORG}, {Giants, ORG}, {The Sporting News, ORG}, {The Sporting News, ORG}, {Wi, MISC}]                                                                                                                                                                                                                                             |
# |Other     |[{Was Truly Shocked To Learn How A Lot Of The Pitt Cast Reacted When Watching The Gory Scenes On Screen The Pitt, MISC}, {The Pitt, MISC}, {Emmy, MISC}, {The Pitt, MISC}]                                                                                                                                                                                                                                                                                   |
# |Technology|[{بأسواق, MISC}, {بأسواق, MISC}, {ONLY, ORG}]                                                                                                                                                                                                                                                                                                                                                                                                              |
# +----------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
from delta.tables import DeltaTable

gold_final_path = "../../sanewsstorage/gold/articles_final"

if DeltaTable.isDeltaTable(spark, gold_final_path):

    delta_table = DeltaTable.forPath(spark, gold_final_path)

    (
        delta_table.alias("t")
        .merge(
            gold_df.alias("s"),
            "t.bronze_hash = s.bronze_hash"
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        gold_df.write
        .format("delta")
        .mode("overwrite")
        .save(gold_final_path)
    )

# %%
gold_df.show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+
# |          article_id|               title|         description|             content|       published_at|language|                 url|            keywords|          categories|             creator|           source_id|         source_name|ingestion_source|         bronze_hash|          clean_text|language_detected|language_final|            entities|           embedding| entities_normalized|     topic|  subtopic|
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+
# |https://whdh.com/...|Officials praise ...|NASHUA, N.H (WHDH...|NASHUA, N.H (WHDH...|2026-02-03 22:43:58|    NULL|https://whdh.com/...|                NULL|                NULL|     [Michael Mahar]|                NULL|Boston News, Weat...|         newsapi|-2133243635794753027|Officials praise ...|               en|            en|[{Nashua, LOC}, {...|[-0.13862129, 0.2...|[{Nashua, LOC}, {...|Technology|Technology|
# |https://www.cbsne...|Heightened securi...|More than 35 loca...|Santa Clara, Cali...|2026-02-07 06:24:31|    NULL|https://www.cbsne...|                NULL|                NULL|  [Kris  Van Cleave]|            cbs-news|            CBS News|         newsapi| 4245083832015084286|Heightened securi...|               en|            en|[{Super Bowl More...|[0.22557996, -0.0...|[{Super Bowl More...|     Other|     Other|
# |d2b9b33c025c8d693...|InventHelp Invent...|PITTSBURGH, Feb. ...|ONLY AVAILABLE IN...|2026-02-03 18:45:00| english|https://www.prnew...|[hou, household, ...|          [business]|[cision pr newswire]|              cision|         Pr Newswire|        newsdata| 2109186896498655789|InventHelp Invent...|               en|       english|[{InventHelp Inve...|[-0.4183713, 0.10...|[{InventHelp Inve...|Technology|Technology|
# |https://economict...|Jennifer Lopez je...|Jennifer Garner’s...|Jennifer Garner i...|2026-02-04 18:50:34|    NULL|https://economict...|                NULL|                NULL|    [Advaita Suresh]|  the-times-of-india|  The Times of India|         newsapi|-3987269010444925942|Jennifer Lopez je...|               en|            en|[{Jennifer Lopez,...|[-0.11635255, 0.1...|[{Jennifer Lopez,...|Technology|Technology|
# |fb68d645-c98e-403...|fit2work unterstü...|Diagnose Krebs un...|Diagnose Krebs un...|2026-02-04 07:00:06|      de|https://www.meinb...|[Available on pai...|[Available on pai...|      [Astrid Moder]|Available on paid...|       Meinbezirk.at|     newsdatahub| 2990353637198350821|fit2work unterstü...|               de|            de|[{fit2work, MISC}...|[-0.124986276, 0....|[{fit2work, MISC}...|Technology|Technology|
# |https://sneakerne...|Victor Wembanyama...|Nike Basketball’s...|Nike Basketball’s...|2026-02-04 21:30:09|    NULL|https://sneakerne...|                NULL|                NULL|      [Andrew Rizzo]|                NULL|        Sneaker News|         newsapi| 3788253699949185581|Victor Wembanyama...|               en|            en|[{Victor Wembanya...|[0.006854076, -0....|[{Victor Wembanya...|     Other|     Other|
# |https://freerepub...|Anson and Avro to...|Two former Underd...|Skip to comments....|2026-02-04 20:30:41|    NULL|https://freerepub...|                NULL|                NULL|  [WisBusiness Blog]|                NULL|    Freerepublic.com|         newsapi| 3516480406649859045|Anson and Avro to...|               en|            en|[{Anson, PER}, {A...|[0.2754762, -0.06...|[{Anson, PER}, {A...|Technology|Technology|
# |https://www.sport...|NFL power ranking...|How do all 32 tea...|NFL power ranking...|2026-02-09 11:37:30|    NULL|https://www.sport...|                NULL|                NULL|       [Vinnie Iyer]|                NULL|       Sporting News|         newsapi|-5772363072248977863|NFL power ranking...|               en|            en|[{NFL, ORG}, {Chi...|[0.058223844, -0....|[{NFL, ORG}, {Chi...|Technology|Technology|
# |https://www.cinem...|I Was Truly Shock...|The Pitt cast wat...|The Pitt is one o...|2026-02-06 08:05:59|    NULL|https://www.cinem...|                NULL|                NULL|       [Dirk Libbey]|                NULL|         CinemaBlend|         newsapi| 4075531572517802277|I Was Truly Shock...|               en|            en|[{Was Truly Shock...|[-0.06840436, -0....|[{Was Truly Shock...|     Other|     Other|
# |92a88881b45b4de6f...|سعر الذهب في مصر ...|يرصد موقع الدستور...|ONLY AVAILABLE IN...|2026-02-07 12:07:22|  arabic|https://www.dosto...|                NULL|               [top]|     [جريدة الدستور]|              dostor|              Dostor|        newsdata|-1804160146961030758|سعر الذهب في مصر ...|               ar|        arabic|[{بأسواق, MISC},...|[-0.22163549, 0.2...|[{بأسواق, MISC},...|Technology|Technology|
# +--------------------+--------------------+--------------------+--------------------+-------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+--------------------+-----------------+--------------+--------------------+--------------------+--------------------+----------+----------+
# only showing top 10 rows
