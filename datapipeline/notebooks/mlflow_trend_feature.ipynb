# %%
import sys
import os

project_root = os.path.abspath("../..")

if project_root not in sys.path:
    sys.path.append(project_root)

os.environ["PYSPARK_PYTHON"] = sys.executable
os.environ["PYSPARK_DRIVER_PYTHON"] = sys.executable

# %%
from datapipeline.utils.spark_session import get_spark_session
spark = get_spark_session("Trend_Feature_Engineering")

# %%
from pyspark.sql.functions import (
    col, lag, sum as spark_sum,
    when, datediff, lit,
    max as spark_max,
    min as spark_min,
    count as spark_count,
    current_date, date_sub
)
from pyspark.sql.window import Window
from delta.tables import DeltaTable

# %%
events_path = os.path.join(project_root, "sanewsstorage/ml/events")
event_lifecycle_path = os.path.join(project_root, "sanewsstorage/ml/event_lifecycle")

events_df = spark.read.format("delta").load(events_path)

# %%
PROCESSING_WINDOW_DAYS = 2

recent_event_dates = (
    events_df
    .filter(col("date") >= date_sub(current_date(), PROCESSING_WINDOW_DAYS))
    .select("cluster_id")
    .distinct()
)

# %%
events_df = (
    events_df
    .filter(col("is_event") == 1)
    .join(recent_event_dates, on="cluster_id", how="inner")
)

# %%
window_spec = Window.partitionBy("cluster_id").orderBy("date")

events_df = (
    events_df
    .withColumn("prev_date", lag("date").over(window_spec))
    .withColumn("date_gap", datediff(col("date"), col("prev_date")))
    .withColumn(
        "new_event_flag",
        when(col("date_gap").isNull(), 1)
        .when(col("date_gap") > 1, 1)
        .otherwise(0)
    )
)

# %%
events_df = events_df.withColumn(
    "event_sequence_id",
    spark_sum("new_event_flag").over(window_spec)
)

# %%
events_df = events_df.withColumn(
    "event_sequence_id",
    spark_sum("new_event_flag").over(window_spec)
)

# %%
events_df = events_df.withColumn(
    "event_score",
    col("article_count") * 0.6 +
    col("z_score") * 25 * 0.4
)

# %%
peak_window = Window.partitionBy("cluster_id", "event_sequence_id")

events_df = events_df.withColumn(
    "peak_volume_event",
    spark_max("article_count").over(peak_window)
)

events_df = events_df.withColumn(
    "is_peak_day",
    when(col("article_count") == col("peak_volume_event"), 1).otherwise(0)
)

# %%
event_lifecycle_df = (
    events_df
    .groupBy("cluster_id", "cluster_label", "event_sequence_id")
    .agg(
        spark_min("date").alias("start_date"),
        spark_max("date").alias("end_date"),
        spark_max(
            when(col("is_peak_day") == 1, col("date"))
        ).alias("peak_date"),
        spark_count("*").alias("duration_days"),
        spark_max("article_count").alias("peak_volume"),
        spark_max("z_score").alias("max_z_score"),
        spark_sum("article_count").alias("total_volume"),
        spark_max("event_score").alias("event_score_peak"),
        spark_max(
            when(col("event_intensity") == "Viral", 3)
            .when(col("event_intensity") == "Trending", 2)
            .otherwise(1)
        ).alias("event_type_rank")
    )
)

# %%
event_lifecycle_df = event_lifecycle_df.withColumn(
    "event_type",
    when(col("event_type_rank") == 3, "Viral")
    .when(col("event_type_rank") == 2, "Trending")
    .otherwise("Emerging")
).drop("event_type_rank")

# %%
event_lifecycle_df = event_lifecycle_df.withColumn(
    "avg_daily_volume",
    col("total_volume") / col("duration_days")
)

# %%
if DeltaTable.isDeltaTable(spark, event_lifecycle_path):

    delta_table = DeltaTable.forPath(spark, event_lifecycle_path)

    (
        delta_table.alias("t")
        .merge(
            event_lifecycle_df.alias("s"),
            """
            t.cluster_id = s.cluster_id
            AND t.event_sequence_id = s.event_sequence_id
            """
        )
        .whenMatchedUpdateAll()
        .whenNotMatchedInsertAll()
        .execute()
    )

else:

    (
        event_lifecycle_df.write
        .format("delta")
        .mode("overwrite")
        .save(event_lifecycle_path)
    )

# %%
result = event_lifecycle_df.orderBy(col("max_z_score").desc())

result.show()
# Out:
# +----------+--------------------+-----------------+----------+----------+----------+-------------+-----------+------------------+------------+------------------+----------+-----------------+
# |cluster_id|       cluster_label|event_sequence_id|start_date|  end_date| peak_date|duration_days|peak_volume|       max_z_score|total_volume|  event_score_peak|event_type| avg_daily_volume|
# +----------+--------------------+-----------------+----------+----------+----------+-------------+-----------+------------------+------------+------------------+----------+-----------------+
# |        15|Trump Policy Repu...|                2|2026-02-20|2026-02-20|2026-02-20|            1|        453| 2.630171388880991|         453| 298.1017138888099|  Trending|            453.0|
# |        10|LLC Makes New Cor...|                2|2026-02-10|2026-02-10|2026-02-10|            1|        612|2.2525323152406385|         612|389.72532315240636|  Trending|            612.0|
# ...

# %%
event_lifecycle_df.orderBy(col("event_score_peak").desc())
# Out:
# DataFrame[cluster_id: bigint, cluster_label: string, event_sequence_id: bigint, start_date: date, end_date: date, duration_days: bigint, peak_volume: bigint, max_z_score: double, total_volume: bigint, event_score_peak: double, event_type: string]

# %%
spark.stop()
